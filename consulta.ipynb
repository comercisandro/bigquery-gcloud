# %%
import pandas as pd

# %%
df=pd.read_csv('/home/sandro/Documentos/beca/experimentos/datosBQ-1-8.csv')

# %%
pd.unique(df.environment)
# Out:
# array(['in', 'out'], dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'record_timestamp', 'run', 'window', 'address', 'rssi',
#        'tx_power', 'advertising_set_id', 'primary_physical_layer',
#        'seconary_physical_layer', 'periodic_advertising_interval',
#        'connectable', 'legacy', 'uuid', 'archive', 'experiment', 'environment',
#        'par1', 'meters', 'par2', 'corrida', 'sensor', 'rx_label', 'tx_label'],
#       dtype='object')

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df_in=df[df.environment=='in']

# %%
dfgrup_in=df_in.groupby(['experiment','par1','par2','meters'])

# %%
recuento=dfgrup_in.count()

# %%
recuento
# Out:
#                                    record_timestamp   run  window  address  \
# experiment par1    par2    meters
# X-h1.1      x(b,r) -x(d,s) 0.00                2308  2308    2308     2308
#                            0.50                 652   652     652      652
#                            1.00                 576   576     576      576
#                            1.50                 693   693     693      693
#                            1.75                 595   595     595      595
# ...                                             ...   ...     ...      ...
# X-v2.4     -z(f,e) -x(o,n) 1.50                 511   511     511      511
#                            1.75                 490   490     490      490
#                            2.00                 447   447     447      447
#                            2.50                 438   438     438      438
#                            3.00                 383   383     383      383
#
# ...

# %%
recuento.to_csv('recuento.csv')
